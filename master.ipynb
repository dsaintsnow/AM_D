# %%
import pandas as pd

dados_texto = pd.read_csv("citacoes.csv")
dados_numericos = pd.read_csv("analise_numpy.csv")
df = pd.merge(
    dados_texto,
    dados_numericos,
    on = "ID"
)
"""print(df.head(2))"""
"""print(df.tail(3))"""
"""print(df.shape)"""
"""print(df.columns)"""
"""print(df.index)"""
"""print(df.dtypes)"""
print("="*50)
